# %% [markdown]
# # "Testing Image Upload"
# > "A sample notebook to test images uploaded in Colab."
#
# - toc: false
# - branch: master
# - badges: true
# - comments: false
# - hide: false
# - search_exclude: true

# %% [markdown]
# ![Screen Shot 2021-01-20 at 9.19.52 AM.png](data:image/png;base64,...)
